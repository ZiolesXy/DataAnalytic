# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiolesXy/DataAnalytic/blob/main/Type_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("telco_churn_mod.csv")

# %%
data.columns
# Out:
# Index(['no', 'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# no                    int64
# customerID           object
# gender              float64
# SeniorCitizen       float64
# Partner             float64
# Dependents          float64
# tenure              float64
# PhoneService        float64
# MultipleLines       float64
# InternetService     float64
# OnlineSecurity      float64
# OnlineBackup        float64
# DeviceProtection    float64
# TechSupport         float64
# StreamingTV         float64
# StreamingMovies     float64
# Contract            float64
# PaperlessBilling    float64
# PaymentMethod       float64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn               float64
# dtype: object

# %% [markdown]
# CustemerId: Nominal
#
# Gender, SeniorCitizen: Binomial. Karena hanya memiliki 2 type/jawaban
#
# InternetService, Tenure: Nominal. karena tidak berurutan

# %%
data.describe()
# Out:
#                 no  gender  SeniorCitizen      Partner   Dependents  \
# count  7101.000000  7052.0    7057.000000  7057.000000  7056.000000
# mean   3549.992255     0.0       0.162109     0.483492     0.299887
# std    2050.013153     0.0       0.368576     0.499763     0.458241
# min       0.000000     0.0       0.000000     0.000000     0.000000
# 25%    1775.000000     0.0       0.000000     0.000000     0.000000
# 50%    3550.000000     0.0       0.000000     0.000000     0.000000
# 75%    5325.000000     0.0       0.000000     1.000000     1.000000
# max    7099.000000     0.0       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7054.000000   7058.000000    7058.000000      7057.000000
# mean     32.390842      0.903230       0.422074         1.126683
# std      24.562537      0.295665       0.493925         0.737783
# min       0.000000      0.000000       0.000000         0.000000
# 25%       9.000000      1.000000       0.000000         1.000000
# 50%      29.000000      1.000000       0.000000         1.000000
# 75%      55.000000      1.000000       1.000000         2.000000
# max      72.000000      1.000000       1.000000         2.000000
#
#        OnlineSecurity  ...  DeviceProtection  TechSupport  StreamingTV  \
# count     7056.000000  ...       7056.000000  7056.000000  7057.000000
# mean         0.286848  ...          0.343679     0.290108     0.384583
# std          0.452322  ...          0.474969     0.453844     0.486531
# min          0.000000  ...          0.000000     0.000000     0.000000
# 25%          0.000000  ...          0.000000     0.000000     0.000000
# 50%          0.000000  ...          0.000000     0.000000     0.000000
# 75%          1.000000  ...          1.000000     1.000000     1.000000
# max          1.000000  ...          1.000000     1.000000     1.000000
#
#        StreamingMovies     Contract  PaperlessBilling  PaymentMethod  \
# count      7058.000000  7057.000000       7057.000000    7057.000000
# mean          0.387929     0.690662          0.591895       2.316140
# std           0.487313     0.833309          0.491518       1.149022
# min           0.000000     0.000000          0.000000       1.000000
# 25%           0.000000     0.000000          0.000000       1.000000
# 50%           0.000000     0.000000          1.000000       2.000000
# 75%           1.000000     1.000000          1.000000       3.000000
# max           1.000000     2.000000          1.000000       4.000000
#
#        MonthlyCharges  TotalCharges        Churn
# count     7054.000000   7043.000000  7058.000000
# mean        64.768769   2285.428525     0.264806
# std         30.102675   2268.418541     0.441261
# min         18.250000     18.800000     0.000000
# 25%         35.500000    401.675000     0.000000
# 50%         70.350000   1398.600000     0.000000
# 75%         89.850000   3798.375000     1.000000
# max        118.750000   8684.800000     1.000000
#
# [8 rows x 21 columns]

# %%
data = data.drop('customerID', axis=1)

# %%
data.var()
# Out:
# no                  4.202554e+06
# gender              0.000000e+00
# SeniorCitizen       1.358486e-01
# Partner             2.497629e-01
# Dependents          2.099844e-01
# tenure              6.033182e+02
# PhoneService        8.741765e-02
# MultipleLines       2.439621e-01
# InternetService     5.443234e-01
# OnlineSecurity      2.045953e-01
# OnlineBackup        2.260944e-01
# DeviceProtection    2.255958e-01
# TechSupport         2.059744e-01
# StreamingTV         2.367124e-01
# StreamingMovies     2.374736e-01
# Contract            6.944040e-01
# PaperlessBilling    2.415896e-01
# PaymentMethod       1.320251e+00
# MonthlyCharges      9.061711e+02
# TotalCharges        5.145723e+06
# Churn               1.947113e-01
# dtype: float64

# %%
data.describe()
# Out:
#                 no  gender  SeniorCitizen      Partner   Dependents  \
# count  7101.000000  7052.0    7057.000000  7057.000000  7056.000000
# mean   3549.992255     0.0       0.162109     0.483492     0.299887
# std    2050.013153     0.0       0.368576     0.499763     0.458241
# min       0.000000     0.0       0.000000     0.000000     0.000000
# 25%    1775.000000     0.0       0.000000     0.000000     0.000000
# 50%    3550.000000     0.0       0.000000     0.000000     0.000000
# 75%    5325.000000     0.0       0.000000     1.000000     1.000000
# max    7099.000000     0.0       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7054.000000   7058.000000    7058.000000      7057.000000
# mean     32.390842      0.903230       0.422074         1.126683
# std      24.562537      0.295665       0.493925         0.737783
# min       0.000000      0.000000       0.000000         0.000000
# 25%       9.000000      1.000000       0.000000         1.000000
# 50%      29.000000      1.000000       0.000000         1.000000
# 75%      55.000000      1.000000       1.000000         2.000000
# max      72.000000      1.000000       1.000000         2.000000
#
#        OnlineSecurity  ...  DeviceProtection  TechSupport  StreamingTV  \
# count     7056.000000  ...       7056.000000  7056.000000  7057.000000
# mean         0.286848  ...          0.343679     0.290108     0.384583
# std          0.452322  ...          0.474969     0.453844     0.486531
# min          0.000000  ...          0.000000     0.000000     0.000000
# 25%          0.000000  ...          0.000000     0.000000     0.000000
# 50%          0.000000  ...          0.000000     0.000000     0.000000
# 75%          1.000000  ...          1.000000     1.000000     1.000000
# max          1.000000  ...          1.000000     1.000000     1.000000
#
#        StreamingMovies     Contract  PaperlessBilling  PaymentMethod  \
# count      7058.000000  7057.000000       7057.000000    7057.000000
# mean          0.387929     0.690662          0.591895       2.316140
# std           0.487313     0.833309          0.491518       1.149022
# min           0.000000     0.000000          0.000000       1.000000
# 25%           0.000000     0.000000          0.000000       1.000000
# 50%           0.000000     0.000000          1.000000       2.000000
# 75%           1.000000     1.000000          1.000000       3.000000
# max           1.000000     2.000000          1.000000       4.000000
#
#        MonthlyCharges  TotalCharges        Churn
# count     7054.000000   7043.000000  7058.000000
# mean        64.768769   2285.428525     0.264806
# std         30.102675   2268.418541     0.441261
# min         18.250000     18.800000     0.000000
# 25%         35.500000    401.675000     0.000000
# 50%         70.350000   1398.600000     0.000000
# 75%         89.850000   3798.375000     1.000000
# max        118.750000   8684.800000     1.000000
#
# [8 rows x 21 columns]

# %%
data[["PaymentMethod", "PaperlessBilling"]].boxplot()
# Out:
# <Axes: >

# %%
data["MonthlyCharges"].plot.hist(bins=100, alpha=0.8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
cv = data.corr()
cv
# Out:
#                         no  gender  SeniorCitizen   Partner  Dependents  \
# no                1.000000     NaN       0.007955  0.001419   -0.004011
# gender                 NaN     NaN            NaN       NaN         NaN
# SeniorCitizen     0.007955     NaN       1.000000  0.015743   -0.211583
# Partner           0.001419     NaN       0.015743  1.000000    0.452642
# Dependents       -0.004011     NaN      -0.211583  0.452642    1.000000
# tenure            0.008530     NaN       0.016998  0.379942    0.159841
# PhoneService     -0.026559     NaN       0.008739  0.018438   -0.002278
# MultipleLines    -0.012954     NaN       0.143433  0.142483   -0.025089
# InternetService   0.006857     NaN       0.032863 -0.001605   -0.044583
# OnlineSecurity   -0.000432     NaN      -0.038067  0.142689    0.081031
# OnlineBackup      0.006054     NaN       0.066399  0.141180    0.023729
# DeviceProtection -0.006728     NaN       0.059061  0.153806    0.012812
# TechSupport       0.008464     NaN      -0.059974  0.119745    0.062413
# StreamingTV       0.000131     NaN       0.105234  0.125040   -0.016740
# StreamingMovies  -0.015223     NaN       0.119396  0.117663   -0.040491
# Contract          0.003745     NaN      -0.142175  0.294681    0.243303
# PaperlessBilling  0.001573     NaN       0.157086 -0.016357   -0.111914
# PaymentMethod    -0.012764     NaN      -0.093847  0.133545    0.123544
# MonthlyCharges   -0.012150     NaN       0.220091  0.097203   -0.114669
# TotalCharges      0.003455     NaN       0.102227  0.319595    0.063927
# Churn             0.008013     NaN       0.150762 -0.150791   -0.164360
#
#                     tenure  PhoneService  MultipleLines  InternetService  \
# no                0.008530     -0.026559      -0.012954         0.006857
# gender                 NaN           NaN            NaN              NaN
# SeniorCitizen     0.016998      0.008739       0.143433         0.032863
# Partner           0.379942      0.018438       0.142483        -0.001605
# Dependents        0.159841     -0.002278      -0.025089        -0.044583
# tenure            1.000000      0.008702       0.332648         0.030931
# PhoneService      0.008702      1.000000       0.279723        -0.387506
# MultipleLines     0.332648      0.279723       1.000000        -0.011040
# InternetService   0.030931     -0.387506      -0.011040         1.000000
# OnlineSecurity    0.327518     -0.093345       0.098378         0.393461
# OnlineBackup      0.360963     -0.052587       0.202369         0.315211
# DeviceProtection  0.360402     -0.070915       0.201514         0.306477
# TechSupport       0.324888     -0.095962       0.101209         0.389433
# StreamingTV       0.280122     -0.022984       0.257910         0.242373
# StreamingMovies   0.286198     -0.032499       0.259250         0.249966
# Contract          0.671631      0.002141       0.107506        -0.098989
# PaperlessBilling  0.005888      0.015860       0.163304         0.138847
# PaymentMethod     0.340591     -0.004203       0.036843        -0.007928
# MonthlyCharges    0.248499      0.247342       0.491096         0.323038
# TotalCharges      0.825945      0.113077       0.469765         0.175576
# Churn            -0.352292      0.011798       0.039753         0.047549
#
#                   OnlineSecurity  ...  DeviceProtection  TechSupport  \
# no                     -0.000432  ...         -0.006728     0.008464
# gender                       NaN  ...               NaN          NaN
# SeniorCitizen          -0.038067  ...          0.059061    -0.059974
# Partner                 0.142689  ...          0.153806     0.119745
# Dependents              0.081031  ...          0.012812     0.062413
# tenure                  0.327518  ...          0.360402     0.324888
# PhoneService           -0.093345  ...         -0.070915    -0.095962
# MultipleLines           0.098378  ...          0.201514     0.101209
# InternetService         0.393461  ...          0.306477     0.389433
# OnlineSecurity          1.000000  ...          0.274895     0.354960
# OnlineBackup            0.284653  ...          0.303265     0.294682
# DeviceProtection        0.274895  ...          1.000000     0.333614
# TechSupport             0.354960  ...          0.333614     1.000000
# StreamingTV             0.176288  ...          0.391055     0.277875
# StreamingMovies         0.186868  ...          0.402800     0.279420
# Contract                0.245859  ...          0.219092     0.293905
# PaperlessBilling       -0.003673  ...          0.103588     0.038162
# PaymentMethod           0.163200  ...          0.111919     0.168177
# MonthlyCharges          0.296518  ...          0.483249     0.338480
# TotalCharges            0.412687  ...          0.523344     0.432882
# Churn                  -0.171219  ...         -0.065823    -0.164341
#
#                   StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# no                   0.000131        -0.015223  0.003745          0.001573
# gender                    NaN              NaN       NaN               NaN
# SeniorCitizen        0.105234         0.119396 -0.142175          0.157086
# Partner              0.125040         0.117663  0.294681         -0.016357
# Dependents          -0.016740        -0.040491  0.243303         -0.111914
# tenure               0.280122         0.286198  0.671631          0.005888
# PhoneService        -0.022984        -0.032499  0.002141          0.015860
# MultipleLines        0.257910         0.259250  0.107506          0.163304
# InternetService      0.242373         0.249966 -0.098989          0.138847
# OnlineSecurity       0.176288         0.186868  0.245859         -0.003673
# OnlineBackup         0.282265         0.274961  0.155437          0.126462
# DeviceProtection     0.391055         0.402800  0.219092          0.103588
# TechSupport          0.277875         0.279420  0.293905          0.038162
# StreamingTV          1.000000         0.533191  0.103956          0.223085
# StreamingMovies      0.533191         1.000000  0.107378          0.210869
# Contract             0.103956         0.107378  1.000000         -0.176600
# PaperlessBilling     0.223085         0.210869 -0.176600          1.000000
# PaymentMethod       -0.012981        -0.003613  0.359086         -0.101568
# MonthlyCharges       0.629754         0.627886 -0.073840          0.351615
# TotalCharges         0.516360         0.520315  0.450179          0.156928
# Churn                0.062852         0.061260 -0.396525          0.191939
#
#                   PaymentMethod  MonthlyCharges  TotalCharges     Churn
# no                    -0.012764       -0.012150      0.003455  0.008013
# gender                      NaN             NaN           NaN       NaN
# SeniorCitizen         -0.093847        0.220091      0.102227  0.150762
# Partner                0.133545        0.097203      0.319595 -0.150791
# Dependents             0.123544       -0.114669      0.063927 -0.164360
# tenure                 0.340591        0.248499      0.825945 -0.352292
# PhoneService          -0.004203        0.247342      0.113077  0.011798
# MultipleLines          0.036843        0.491096      0.469765  0.039753
# InternetService       -0.007928        0.323038      0.175576  0.047549
# OnlineSecurity         0.163200        0.296518      0.412687 -0.171219
# OnlineBackup           0.096732        0.441925      0.510259 -0.082619
# DeviceProtection       0.111919        0.483249      0.523344 -0.065823
# TechSupport            0.168177        0.338480      0.432882 -0.164341
# StreamingTV           -0.012981        0.629754      0.516360  0.062852
# StreamingMovies       -0.003613        0.627886      0.520315  0.061260
# Contract               0.359086       -0.073840      0.450179 -0.396525
# PaperlessBilling      -0.101568        0.351615      0.156928  0.191939
# PaymentMethod          1.000000       -0.073763      0.223329 -0.262702
# MonthlyCharges        -0.073763        1.000000      0.651628  0.192929
# TotalCharges           0.223329        0.651628      1.000000 -0.199691
# Churn                 -0.262702        0.192929     -0.199691  1.000000
#
# [21 rows x 21 columns]

# %%
sns.heatmap(cv, annot=True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(cv, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Korelasi positiv:
#
#    * Total Charge & Tenure
#    * Tenure & Contract
#    * Montly Charge & Total Charge
#
# Korelasi negatif:
#
#    * contract & Churn
#    * Tenure & Churn
#    * Internet Service & Phone Service

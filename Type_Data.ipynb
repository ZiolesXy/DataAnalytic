# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiolesXy/DataAnalytic/blob/main/Type_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("telco_churn_mod.csv")

# %%
data.isna().sum()
# Out:
# no                   0
# customerID          33
# gender              49
# SeniorCitizen       44
# Partner             44
# Dependents          45
# tenure              47
# PhoneService        43
# MultipleLines       43
# InternetService     44
# OnlineSecurity      45
# OnlineBackup        43
# DeviceProtection    45
# TechSupport         45
# StreamingTV         44
# StreamingMovies     43
# Contract            44
# PaperlessBilling    44
# PaymentMethod       44
# MonthlyCharges      47
# TotalCharges        58
# Churn               43
# dtype: int64

# %%
data.fillna({'gender':0,	'SeniorCitizen':0, 'Partner':0,
            'Dependents':0,	'tenure':32.3, 'PhoneService':1, 'MultipleLines':0,
            'InternetService':1, 'OnlineSecurity':0,
            'OnlineBackup':0, 'DeviceProtection':0, 'TechSupport':0,
            'StreamingTV':0, 'StreamingMovies':0, 'Contract':0,
            'PaperlessBilling':1,	'PaymentMethod':1, 'MonthlyCharges':64.7, 'TotalCharges':2285.4},
           inplace=True)

# %%
data.columns
# Out:
# Index(['no', 'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# no                    int64
# customerID           object
# gender              float64
# SeniorCitizen       float64
# Partner             float64
# Dependents          float64
# tenure              float64
# PhoneService        float64
# MultipleLines       float64
# InternetService     float64
# OnlineSecurity      float64
# OnlineBackup        float64
# DeviceProtection    float64
# TechSupport         float64
# StreamingTV         float64
# StreamingMovies     float64
# Contract            float64
# PaperlessBilling    float64
# PaymentMethod       float64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn               float64
# dtype: object

# %% [markdown]
# CustemerId: Nominal
#
# Gender, SeniorCitizen: Binomial. Karena hanya memiliki 2 type/jawaban
#
# InternetService, Tenure: Nominal. karena tidak berurutan

# %%
data.describe()
# Out:
#                 no  gender  SeniorCitizen      Partner   Dependents  \
# count  7101.000000  7101.0    7101.000000  7101.000000  7101.000000
# mean   3549.992255     0.0       0.161104     0.480496     0.297986
# std    2050.013153     0.0       0.367653     0.499655     0.457406
# min       0.000000     0.0       0.000000     0.000000     0.000000
# 25%    1775.000000     0.0       0.000000     0.000000     0.000000
# 50%    3550.000000     0.0       0.000000     0.000000     0.000000
# 75%    5325.000000     0.0       0.000000     1.000000     1.000000
# max    7099.000000     0.0       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7101.000000   7101.000000    7101.000000      7101.000000
# mean     32.390241      0.903816       0.419518         1.125898
# std      24.481105      0.294864       0.493515         0.735560
# min       0.000000      0.000000       0.000000         0.000000
# ...

# %%
data = data.drop('customerID', axis=1)

# %%
data.var()
# Out:
# no                  4.202554e+06
# gender              0.000000e+00
# SeniorCitizen       1.351686e-01
# Partner             2.496547e-01
# Dependents          2.092199e-01
# tenure              5.993245e+02
# PhoneService        8.694459e-02
# MultipleLines       2.435570e-01
# InternetService     5.410489e-01
# OnlineSecurity      2.038167e-01
# OnlineBackup        2.254427e-01
# DeviceProtection    2.249098e-01
# TechSupport         2.051990e-01
# StreamingTV         2.361563e-01
# StreamingMovies     2.369413e-01
# Contract            6.930385e-01
# PaperlessBilling    2.411182e-01
# PaymentMethod       1.322738e+00
# MonthlyCharges      9.001725e+02
# TotalCharges        5.103687e+06
# Churn               1.947113e-01
# dtype: float64

# %%
data.describe()
# Out:
#                 no  gender  SeniorCitizen      Partner   Dependents  \
# count  7101.000000  7101.0    7101.000000  7101.000000  7101.000000
# mean   3549.992255     0.0       0.161104     0.480496     0.297986
# std    2050.013153     0.0       0.367653     0.499655     0.457406
# min       0.000000     0.0       0.000000     0.000000     0.000000
# 25%    1775.000000     0.0       0.000000     0.000000     0.000000
# 50%    3550.000000     0.0       0.000000     0.000000     0.000000
# 75%    5325.000000     0.0       0.000000     1.000000     1.000000
# max    7099.000000     0.0       1.000000     1.000000     1.000000
#
#             tenure  PhoneService  MultipleLines  InternetService  \
# count  7101.000000   7101.000000    7101.000000      7101.000000
# mean     32.390241      0.903816       0.419518         1.125898
# std      24.481105      0.294864       0.493515         0.735560
# min       0.000000      0.000000       0.000000         0.000000
# ...

# %%
data[["PaymentMethod", "PaperlessBilling"]].boxplot()
# Out:
# <Axes: >

# %%
data["MonthlyCharges"].plot.hist(bins=100, alpha=0.8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
cv = data.corr()
cv
# Out:
#                         no  gender  SeniorCitizen   Partner  Dependents  \
# no                1.000000     NaN       0.003193 -0.008877   -0.011092
# gender                 NaN     NaN            NaN       NaN         NaN
# SeniorCitizen     0.003193     NaN       1.000000  0.017874   -0.209296
# Partner          -0.008877     NaN       0.017874  1.000000    0.454357
# Dependents       -0.011092     NaN      -0.209296  0.454357    1.000000
# tenure            0.008404     NaN       0.016894  0.378690    0.159637
# PhoneService     -0.022906     NaN       0.007840  0.016422   -0.003629
# MultipleLines    -0.021685     NaN       0.145214  0.146566   -0.021651
# InternetService   0.004964     NaN       0.033318 -0.000599   -0.043704
# OnlineSecurity   -0.007331     NaN      -0.036552  0.145779    0.083126
# OnlineBackup     -0.001558     NaN       0.068088  0.144877    0.026464
# DeviceProtection -0.014528     NaN       0.060845  0.157392    0.015832
# ...

# %%
sns.heatmap(cv, annot=True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(cv, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Korelasi positiv:
#
#    * Total Charge & Tenure
#    * Tenure & Contract
#    * Montly Charge & Total Charge
#
# Korelasi negatif:
#
#    * contract & Churn
#    * Tenure & Churn
#    * Internet Service & Phone Service
#
#    Churn Positive:
# 1. Churn & PaperlessBilling: 0.19
# 2. Cum & MonthlyCharges: 0.19
#
# Cum Negative:
# 1. Churn & Contract: -0.4
# 2. Churn & tenure: -0.35

# %%
data.isna().sum()
# Out:
# no                   0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges         0
# Churn               43
# dtype: int64

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (7058, 21)

# %%
x_data = data[["PaperlessBilling", "MonthlyCharges", "tenure", "MultipleLines", "TotalCharges"]]
y_data = data["Churn"]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(x_data, y_data, test_size=0.3, random_state = 42)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(x_data, y_data, test_size=0.3, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1397  147]
#  [ 308  266]]

# %%
# accuracy: Accuracy = (TP + TN)/(TP + FP + TN + FN)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))

# precision: Precision = TP/(TP + FP)
from sklearn.metrics import precision_score
print(precision_score(y_test, y_pred))

# recall: Recall = TP/(TP + FN)
from sklearn.metrics import recall_score
print(recall_score(y_test, y_pred))

# F1 score weighted average of precision and recall
from sklearn.metrics import f1_score
print(f1_score(y_test, y_pred))
# Out:
# 0.7851746931067044
# 0.6440677966101694
# 0.4634146341463415
# 0.5390070921985816

# %%
data["Churn"].plot.bar()
# Out:
# <Axes: >
